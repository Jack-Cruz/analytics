# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Arithmetic and Data Alignment

# %% [markdown]
# ## Sorting and Ranking

# %% [markdown]
# ### Sorting index

# %%
df1 = pd.DataFrame(np.arange(12).reshape((3, 4)),
                   index=['three', 'one', 'two'],
                   columns=['c', 'a', 'b', 'd'])
df1
# Out:
#        c  a   b   d
# three  0  1   2   3
# one    4  5   6   7
# two    8  9  10  11

# %% [markdown]
# Sort a DataFrame by its index:

# %%
df1.sort_index()
# Out:
#        c  a   b   d
# one    4  5   6   7
# three  0  1   2   3
# two    8  9  10  11

# %% [markdown]
# Sort a DataFrame by columns name's in descending order.

# %%
df1.sort_index(axis=1, ascending=False)
# Out:
#         d  c   b  a
# three   3  0   2  1
# one     7  4   6  5
# two    11  8  10  9

# %% [markdown]
# ### Sort values

# %% [markdown]
# Sort a DataFrame's values by column:

# %%
df1.sort_values(by=['d', 'c'])
# Out:
#        c  a   b   d
# three  0  1   2   3
# one    4  5   6   7
# two    8  9  10  11

# %%
# modify some values

df2 = df1.copy()

df2['b'][0] = 10
df2['d'][1] = 3

df2
# Out:
#        c  a   b   d
# three  0  1  10   3
# one    4  5   6   3
# two    8  9  10  11

# %%
df2.sort_values(by=['d', 'b'])
# Out:
#        c  a   b   d
# one    4  5   6   3
# three  0  1  10   3
# two    8  9  10  11

# %% [markdown]
# ### Ranking
#
# DataFrames can rank over rows or columns.

# %%
df3 = pd.DataFrame( {'foo' : [7, -5, 7, 4, 2, 0, 4, 7],
                     'bar' : [-5, 4, 2, 0, 4, 7, 7, 8],
                     'baz' : [-1, 2, 3, 0, 5, 9, 9, 5]} )
df3
# Out:
#    foo  bar  baz
# 0    7   -5   -1
# 1   -5    4    2
# 2    7    2    3
# 3    4    0    0
# 4    2    4    5
# 5    0    7    9
# 6    4    7    9
# 7    7    8    5

# %% [markdown]
# Rank a DataFrame over rows:

# %%
df3.rank()
# Out:
#    foo  bar  baz
# 0  7.0  1.0  1.0
# 1  1.0  4.5  3.0
# 2  7.0  3.0  4.0
# 3  4.5  2.0  2.0
# 4  3.0  4.5  5.5
# 5  2.0  6.5  7.5
# 6  4.5  6.5  7.5
# 7  7.0  8.0  5.5

# %% [markdown]
# Rank a DataFrame over columns:

# %%
df3
# Out:
#    foo  bar  baz
# 0    7   -5   -1
# 1   -5    4    2
# 2    7    2    3
# 3    4    0    0
# 4    2    4    5
# 5    0    7    9
# 6    4    7    9
# 7    7    8    5

# %%
df3.rank(axis=1)
# Out:
#    foo  bar  baz
# 0  3.0  1.0  2.0
# 1  1.0  3.0  2.0
# 2  3.0  1.0  2.0
# 3  3.0  1.5  1.5
# 4  1.0  2.0  3.0
# 5  1.0  2.0  3.0
# 6  1.0  2.0  3.0
# 7  2.0  3.0  1.0

# %% [markdown]
# ## Axis Indexes with Duplicate Values

# %% [markdown]
# Select DataFrame elements

# %%
df4 = pd.DataFrame(np.random.randn(5, 4),
                  index=['foo', 'foo', 'bar', 'bar', 'baz'])
df4
# Out:
#             0         1         2         3
# foo  1.159627  0.237311  1.411635 -1.291075
# foo  0.620218 -0.025740 -1.792992 -0.363275
# bar  0.446185  0.637069 -1.574358 -0.451090
# bar -0.787725  2.061500  1.149316 -0.441779
# baz -0.475877  0.398953  0.054429  0.077788

# %%
df4.loc['bar']
# Out:
#             0         1         2         3
# bar  0.446185  0.637069 -1.574358 -0.451090
# bar -0.787725  2.061500  1.149316 -0.441779
